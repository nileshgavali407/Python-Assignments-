# %%
#Assignment 1- Take multiple values as input and print sum of them
a = int(input('Enter the no: '))
b = int(input('Enter the  no: '))
c = int(input('Enter the no: '))
d = int(input('Enter the no: '))
f = int(input('Enter the no: '))
g = int(input('Enter the no: '))
h = int(input('Enter the no: '))
i = int(input('Enter the no: '))
print('Sum:', a+b+c+d+f+g+h+i)
# Out:
# Enter the no: 22
# Enter the  no: 33
# Enter the no: 44
# Enter the no: 55
# Enter the no: 22
# Enter the no: 11
# Enter the no: 44
# Enter the no: 55
# Sum: 286
